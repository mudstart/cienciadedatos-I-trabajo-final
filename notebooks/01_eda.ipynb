# %%
import sys
sys.path.append('../src')
from db import engine
import pandas as pd

df = pd.read_sql("SELECT 1", engine)
print("Conexión exitosa", df)
# Out:
# Conexión exitosa    1
# 0  1

# %%
df = pd.read_sql("SELECT * FROM student_info LIMIT 5", engine)
df.head()
# Out:
#    id_student code_module code_presentation gender               region  \
# 0        3733         DDD             2013J      M         South Region
# 1        6516         AAA             2014J      M             Scotland
# 2        8462         DDD             2013J      M        London Region
# 3        8462         DDD             2014J      M        London Region
# 4       11391         AAA             2013J      M  East Anglian Region
#
#   highest_education imd_band age_band  num_of_prev_attempts  studied_credits  \
# 0  HE Qualification  90-100%     55<=                     0               60
# 1  HE Qualification   80-90%     55<=                     0               60
# 2  HE Qualification   30-40%     55<=                     0               90
# 3  HE Qualification   30-40%     55<=                     1               60
# 4  HE Qualification  90-100%     55<=                     0              240
#
#   disability final_result  gender_ord  highest_education_ord  imd_band_ord  \
# 0          N    Withdrawn           1                      4            10
# 1          N         Pass           1                      4             9
# 2          N    Withdrawn           1                      4             4
# 3          N    Withdrawn           1                      4             4
# 4          N         Pass           1                      4            10
#
#    age_band_ord  disability_ord  final_result_ord
# 0             3               0                 0
# 1             3               0                 2
# 2             3               0                 0
# 3             3               0                 0
# 4             3               0                 2
